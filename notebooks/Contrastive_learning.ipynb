# %%
# !nvidia-smi
# Out:
# Thu Oct  7 11:23:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
cd drive/MyDrive/kaggle/petfinder/dino
# Out:
# /content/drive/MyDrive/kaggle/petfinder/dino

# %%
# !pip install lightly
# !git clone https://github.com/facebookresearch/dino.git

# !pip install submitit
# !pip install timm
# Out:
# ...
#      |████████████████████████████████| 69 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 376 kB 13.4 MB/s
# ...

# %%
# !python main_dino.py \
--arch "vit_small" \
--data_path "/content/drive/MyDrive/kaggle/petfinder/petfinder-pawpularity-score" \
--output_dir "./dino_weights_1024" \
--epochs 200 \
--out_dim 1024 \
--batch_size_per_gpu 56
# Out:
# Will run the code on one GPU.
# | distributed init (rank 0): env://
# [W ProcessGroupNCCL.cpp:1569] Rank 0 using best-guess GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device.
# git:
#   sha: 499d9e2b3d903355f67e86f9def06bccb4222b1f, status: has uncommited changes, branch: main
#
# arch: vit_small
# batch_size_per_gpu: 56
# clip_grad: 3.0
# data_path: /content/drive/MyDrive/kaggle/petfinder/petfinder-pawpularity-score
# dist_url: env://
# drop_path_rate: 0.1
# epochs: 200
# freeze_last_layer: 1
# global_crops_scale: (0.4, 1.0)
# gpu: 0
# local_crops_number: 8
# local_crops_scale: (0.05, 0.4)
# local_rank: 0
# lr: 0.0005
# min_lr: 1e-06
# momentum_teacher: 0.996
# norm_last_layer: True
# num_workers: 10
# optimizer: adamw
# out_dim: 1024
# output_dir: ./dino_weights_1024
# patch_size: 16
# rank: 0
# ...
